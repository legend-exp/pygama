# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.linspace(0,10,1000)
bin_heights, bin_borders,_ = plt.hist(a, bins = np.linspace(-0,10,150))

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.subplots(figsize=(16,6))
# Out:
# (<Figure size 1152x432 with 1 Axes>, <AxesSubplot:>)
